# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = "svg"

# %%
df = pd.read_csv("/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/kaggle_survey_2021_responses.csv")
# Out:
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                     910                        50-54
# 2                                     784                        50-54
# 3                                     924                        22-24
# 4                                     575                        45-49
# ...                                   ...                          ...
# 25969                                1756                        30-34
# 25970                                 253                        22-24
# 25971                                 494                        50-54
# 25972                                 277                        45-49
# 25973                                 255                        18-21
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# 4                                         Man
# ...                                       ...
# 25969                                     Man
# 25970                                     Man
# 25971                                     Man
# 25972                                     Man
# 25973                                     Man
#
#                                               Q3  \
# 0      In which country do you currently reside?
# 1                                          India
# 2                                      Indonesia
# 3                                       Pakistan
# 4                                         Mexico
# ...                                          ...
# 25969                                      Egypt
# 25970                                      China
# 25971                                     Sweden
# 25972                   United States of America
# 25973                                      India
#
#                                                       Q4  \
# 0      What is the highest level of formal education ...
# 1                                      Bachelor’s degree
# 2                                        Master’s degree
# 3                                        Master’s degree
# 4                                        Doctoral degree
# ...                                                  ...
# 25969                                  Bachelor’s degree
# 25970                                    Master’s degree
# 25971                                    Doctoral degree
# 25972                                    Master’s degree
# 25973                                  Bachelor’s degree
#
#                                                       Q5  \
# 0      Select the title most similar to your current ...
# 1                                                  Other
# 2                                Program/Project Manager
# 3                                      Software Engineer
# 4                                     Research Scientist
# ...                                                  ...
# 25969                                       Data Analyst
# 25970                                            Student
# 25971                                 Research Scientist
# 25972                                     Data Scientist
# 25973                                   Business Analyst
#
#                                                       Q6  \
# 0      For how many years have you been writing code ...
# 1                                             5-10 years
# 2                                              20+ years
# 3                                              1-3 years
# 4                                              20+ years
# ...                                                  ...
# 25969                                          1-3 years
# 25970                                          1-3 years
# 25971                          I have never written code
# 25972                                         5-10 years
# 25973                          I have never written code
#
#                                                Q7_Part_1  \
# 0      What programming languages do you use on a reg...
# 1                                                 Python
# 2                                                    NaN
# 3                                                 Python
# 4                                                 Python
# ...                                                  ...
# 25969                                             Python
# 25970                                             Python
# 25971                                                NaN
# 25972                                             Python
# 25973                                                NaN
#
#                                                Q7_Part_2  \
# 0      What programming languages do you use on a reg...
# 1                                                      R
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
#
#                                                Q7_Part_3  ...  \
# 0      What programming languages do you use on a reg...  ...
# 1                                                    NaN  ...
# 2                                                    SQL  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 25969                                                SQL  ...
# 25970                                                NaN  ...
# 25971                                                NaN  ...
# 25972                                                SQL  ...
# 25973                                                NaN  ...
#
#                                             Q38_B_Part_3  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
#
#                                             Q38_B_Part_4  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
#
#                                             Q38_B_Part_5  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                           TensorBoard
# 4                                                    NaN
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
#
#                                             Q38_B_Part_6  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
#
#                                             Q38_B_Part_7  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
#
#                                             Q38_B_Part_8  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
#
#                                             Q38_B_Part_9  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
#
#                                            Q38_B_Part_10  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
#
#                                            Q38_B_Part_11  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                   None
# 3                                                    NaN
# 4                                                   None
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                               None
# 25972                                                NaN
# 25973                                               None
#
#                                              Q38_B_OTHER
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
#
# [25974 rows x 369 columns]

# %%
df.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 910                        50-54
# 2                                 784                        50-54
# 3                                 924                        22-24
# 4                                 575                        45-49
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                  Indonesia
# 3                                   Pakistan
# 4                                     Mexico
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                  Bachelor’s degree
# 2                                    Master’s degree
# 3                                    Master’s degree
# 4                                    Doctoral degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                              Other
# 2                            Program/Project Manager
# 3                                  Software Engineer
# 4                                 Research Scientist
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                                         5-10 years
# 2                                          20+ years
# 3                                          1-3 years
# 4                                          20+ years
#
#                                            Q7_Part_1  \
# 0  What programming languages do you use on a reg...
# 1                                             Python
# 2                                                NaN
# 3                                             Python
# 4                                             Python
#
#                                            Q7_Part_2  \
# 0  What programming languages do you use on a reg...
# 1                                                  R
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_3  ...  \
# 0  What programming languages do you use on a reg...  ...
# 1                                                NaN  ...
# 2                                                SQL  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#                                         Q38_B_Part_3  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_4  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_5  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                       TensorBoard
# 4                                                NaN
#
#                                         Q38_B_Part_6  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_7  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_8  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_9  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q38_B_Part_10  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q38_B_Part_11  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                               None
# 3                                                NaN
# 4                                               None
#
#                                          Q38_B_OTHER
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 369 columns]

# %%
df.tail()
# Out:
#       Time from Start to Finish (seconds)     Q1   Q2  \
# 25969                                1756  30-34  Man
# 25970                                 253  22-24  Man
# 25971                                 494  50-54  Man
# 25972                                 277  45-49  Man
# 25973                                 255  18-21  Man
#
#                              Q3                 Q4                  Q5  \
# 25969                     Egypt  Bachelor’s degree        Data Analyst
# 25970                     China    Master’s degree             Student
# 25971                    Sweden    Doctoral degree  Research Scientist
# 25972  United States of America    Master’s degree      Data Scientist
# 25973                     India  Bachelor’s degree    Business Analyst
#
#                               Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 25969                  1-3 years    Python       NaN       SQL  ...
# 25970                  1-3 years    Python       NaN       NaN  ...
# 25971  I have never written code       NaN       NaN       NaN  ...
# 25972                 5-10 years    Python       NaN       SQL  ...
# 25973  I have never written code       NaN       NaN       NaN  ...
#
#       Q38_B_Part_3 Q38_B_Part_4 Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7  \
# 25969          NaN          NaN          NaN          NaN          NaN
# 25970          NaN          NaN          NaN          NaN          NaN
# 25971          NaN          NaN          NaN          NaN          NaN
# 25972          NaN          NaN          NaN          NaN          NaN
# 25973          NaN          NaN          NaN          NaN          NaN
#
#       Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 25969          NaN          NaN           NaN           NaN         NaN
# 25970          NaN          NaN           NaN           NaN         NaN
# 25971          NaN          NaN           NaN          None         NaN
# 25972          NaN          NaN           NaN           NaN         NaN
# 25973          NaN          NaN           NaN          None         NaN
#
# [5 rows x 369 columns]

# %%
df.describe()
# Out:
#         Time from Start to Finish (seconds)     Q1     Q2     Q3  \
# count                                 25974  25974  25974  25974
# unique                                 5410     12      6     67
# top                                     484  25-29    Man  India
# freq                                     42   4931  20598   7434
#
#                      Q4       Q5         Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# count             25974    25974      25974     21861      5335     10757
# unique                8       16          8         2         2         2
# top     Master’s degree  Student  1-3 years    Python         R       SQL
# freq              10132     6804       7874     21860      5334     10756
#
#         ... Q38_B_Part_3          Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6  \
# count   ...          634                   592           4240          730
# unique  ...            2                     2              2            2
# top     ...    Comet.ml    Sacred + Omniboard    TensorBoard     Guild.ai
# freq    ...          633                   591           4239          729
#
#        Q38_B_Part_7 Q38_B_Part_8            Q38_B_Part_9 Q38_B_Part_10  \
# count           738         1021                     667          2748
# unique            2            2                       2             2
# top       Polyaxon      ClearML    Domino Model Monitor        MLflow
# freq            737         1020                     666          2747
#
#        Q38_B_Part_11 Q38_B_OTHER
# count           4543         378
# unique             2           2
# top             None       Other
# freq            4542         377
#
# [4 rows x 369 columns]

# %%
df.drop(df.index[0],inplace=True)

# %%
df["Q2"].unique()
# Out:
# array(['Man', 'Woman', 'Nonbinary', 'Prefer not to say',
#        'Prefer to self-describe'], dtype=object)

# %%
df.drop(df[df["Q2"].isin(['Nonbinary', 'Prefer not to say', 'Prefer to self-describe'])].index, inplace=True)

# %% [markdown]
# ## Let's see the questions answered by 50% of the Kaggle community

# %%
n = []
for i in df:
    if df[i].isnull().sum() > 25974/2:   #25974 in number of Respondents 
        n.append(i)    
        
df50 = df.drop(n,axis = 1)
df50.drop(df.index[0],inplace=True)

df50.isna().sum()
# Out:
# Time from Start to Finish (seconds)        0
# Q1                                         0
# Q2                                         0
# Q3                                         0
# Q4                                         0
# Q5                                         0
# Q6                                         0
# Q7_Part_1                               4029
# Q8                                      1016
# Q9_Part_11                              9532
# Q11                                     1232
# Q12_Part_5                             12495
# Q13                                     1541
# Q14_Part_1                              8187
# Q15                                     2181
# Q16_Part_1                             11731
# Q17_Part_1                             11870
# Q20                                     9450
# Q21                                     9524
# Q22                                     9645
# Q23                                     9816
# Q25                                    10364
# Q26                                    10569
# Q41                                     7341
# dtype: int64

# %% [markdown]
# # Gender

# %%
df_g=df['Q2'].value_counts()
colors = ['dodgerblue', 'mediumturquoise']
labels=df_g.index

fig,ax1=plt.subplots(1,1,figsize=(5,5))
ax1.pie(df_g,colors = colors,labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis("equal")
plt.title("Gender",fontsize=26, weight = 'bold',color="black")
plt.savefig("Gender.jpg")
plt.show()

# %% [markdown]
# # Age Group

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(8,8))
sns.countplot(y = 'Q1',data = df,order = df['Q1'].value_counts().index,palette = "viridis")
plt.ylabel('Age Group',fontsize = 20, weight = 'bold',color='black')
plt.axes().set(facecolor = "White")
plt.show()
# Out:
# <ipython-input-13-c7e34a77c017>:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %% [markdown]
# # Job

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(8,8))
sns.countplot(y = 'Q5',
              data = df,
              order = df['Q5'].value_counts().index,palette= 'viridis')
plt.xticks(size = 12)
plt.ylabel('Job',fontsize = 20, weight = 'bold',color='black');
plt.axes().set(facecolor = "White")
plt.show()
# Out:
# <ipython-input-14-b087d92f522a>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %% [markdown]
# # Education

# %%
def degree_cleaning(x):
    if x=='Some college/university study without earning a bachelor’s degree':
        x='College without degree'
    elif x=='I prefer not to answer':
        x='No-response'
    elif x=='No formal education past high school':
        x='After high school'
    return x
df['Q4']=df['Q4'].map(lambda x: degree_cleaning(x))

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(8,8))
sns.countplot(y = 'Q4',
              data = df,
              order = df['Q4'].value_counts().index,palette= 'viridis')
plt.ylabel('Education',fontsize = 20, weight = 'bold',color='black')
plt.axes().set(facecolor = "White")
plt.show()
# Out:
# <ipython-input-16-58ca44a50d85>:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %% [markdown]
# # Experience

# %%
def code_cleaning(x):
    if x=='I have never written code':
        x='0years'
    return x
df['Q6']=df['Q6'].map(lambda x: code_cleaning(x))

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(8,8))
sns.countplot(y = 'Q6',
              data = df,
              order = df['Q6'].value_counts().index , palette= 'viridis')
plt.xticks(size = 12)
plt.ylabel('Years of Experience',fontsize = 20, weight = 'bold',color='black')
plt.axes().set(facecolor = "White")
plt.show()
# Out:
# <ipython-input-18-07d2afe6e040>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %% [markdown]
# # Salary

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(8,8))
sns.countplot(y = 'Q25',
              data = df,
              order = df['Q25'].value_counts().index,palette= 'viridis')
plt.xticks(size = 12)
plt.ylabel('Salary',fontsize = 20, weight = 'bold',color='black')
plt.axes().set(facecolor = "White")
plt.savefig("Salary.jpg")
plt.show()
# Out:
# <ipython-input-19-f44e7eee329a>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %% [markdown]
# # Country

# %%
def country_cleaning(x):
    if x=='United States of America':
        x='USA'
    elif x=='United Kingdom of Great Britain and Northern Ireland':
        x='UK'
    return x
df['Q3']=df['Q3'].map(lambda x: country_cleaning(x))

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(7,7))
sns.countplot(y = 'Q3',
              data = df,
              order = df['Q3'].value_counts().sort_values(ascending= False).head(10).index,palette= 'viridis')
plt.ylabel('Country',fontsize = 20, weight = 'bold',color='black')
plt.axes().set(facecolor = "White")
plt.show()
# Out:
# <ipython-input-21-61934f3ceff1>:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %% [markdown]
# ## Education&Experience

# %%
plt.figure(figsize=(10, 8))
sns.countplot(data=df, x=df['Q6'], hue=df['Q4'], order=df['Q6'].value_counts().index,palette= 'viridis')
sns.despine()
plt.title('Education&Experience',fontsize = 20, weight = 'bold',color='black')
plt.xlabel('Experience',fontsize = 10, weight = 'bold',color='black')
plt.ylabel('Education',fontsize = 10, weight = 'bold',color='black')
plt.savefig("Education&Experience.jpg")
plt.axes().set(facecolor = "White")
plt.show()
# Out:
# <ipython-input-22-d88077ed7b4a>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %%
Q7 = [col for col in df if col.startswith('Q7')]
df7 = df[Q7]
df7
# Out:
#       Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6   Q7_Part_7  \
# 1        Python         R       NaN       NaN       NaN       NaN         NaN
# 2           NaN       NaN       SQL         C       C++      Java         NaN
# 3        Python       NaN       NaN       NaN       C++      Java         NaN
# 4        Python       NaN       NaN       NaN       NaN       NaN         NaN
# 5        Python       NaN       NaN         C       NaN       NaN         NaN
# ...         ...       ...       ...       ...       ...       ...         ...
# 25969    Python       NaN       SQL       NaN       NaN       NaN  Javascript
# 25970    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 25971       NaN       NaN       NaN       NaN       NaN       NaN         NaN
# 25972    Python       NaN       SQL       NaN       NaN       NaN         NaN
# 25973       NaN       NaN       NaN       NaN       NaN       NaN         NaN
#
#       Q7_Part_8 Q7_Part_9 Q7_Part_10 Q7_Part_11 Q7_Part_12 Q7_OTHER
# 1           NaN       NaN        NaN        NaN        NaN      NaN
# 2           NaN       NaN        NaN        NaN        NaN      NaN
# 3           NaN       NaN        NaN        NaN        NaN      NaN
# 4           NaN       NaN        NaN        NaN        NaN      NaN
# 5           NaN       NaN        NaN     MATLAB        NaN      NaN
# ...         ...       ...        ...        ...        ...      ...
# 25969       NaN       NaN       Bash        NaN        NaN      NaN
# 25970       NaN       NaN        NaN        NaN        NaN      NaN
# 25971       NaN       NaN        NaN        NaN        NaN      NaN
# 25972       NaN       NaN        NaN        NaN        NaN      NaN
# 25973       NaN       NaN        NaN        NaN        NaN      NaN
#
# [25488 rows x 13 columns]

# %% [markdown]
# ## Most used programming languages in 2021

# %%
df7.columns = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 'Javascript', 'Julia', 'Swift', 'Bash', 'MATLAB', 'None', 'Other']
plt.figure(figsize=(8,8))
df7.count().sort_values(ascending=False).plot(kind = 'bar',color=["dodgerblue"]);
plt.title('Most used programming languages in 2021',fontsize = 20, weight = 'bold',color='black');
plt.axes().set(facecolor = "White")
plt.show();
# Out:
# <ipython-input-24-db69ab834f13>:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %% [markdown]
# ## Most used (IDE's) in 2021

# %%
Q9 = [col for col in df if col.startswith('Q9')]
df9 = df[Q9]
df99 = df9.iloc[:, : 12]

# %%
df99.columns = ['Jupyter (Lab, etc)',' RStudio','Visual Studio','VSCode',
              'PyCharm','Spyder','Notepad++','Sublime Text','Vim / Emacs','MATLAB','Jupyter Notebook','Other']

plt.figure(figsize=(7,7))
df99.count().sort_values(ascending=False).plot(kind = 'bar',color=["dodgerblue"]);
plt.title("Most used (IDE's) for 2021",fontsize = 20, weight = 'bold',color='black');
plt.axes().set(facecolor = "White")
plt.show();
# Out:
# <ipython-input-26-d287f6fb4f34>:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %% [markdown]
# # Most used of notebook products in 2021

# %%
Q10 = [col for col in df if col.startswith('Q10')]
df10 = df[Q10]
df100 = df10.iloc[:, : 15]
df100

df100.columns = ['Kaggle Notebooks','Colab Notebooks','Azure Notebooks','Paperspace / Gradient','Binder / JupyterHub','Code Ocean','IBM Watson Studio',
              'Amazon Notebooks','Amazon EMR Notebooks','Google Cloud','Google Cloud Datalab',
              'Databricks Notebooks','Zeppelin / Zepl Notebooks','Deepnote Notebooks','Observable Notebooks']

plt.figure(figsize=(8,8))
df100.count().sort_values(ascending=True).plot(kind = 'barh',color=["dodgerblue"]);
plt.title("Most used of notebook products in 2021",fontsize = 20, weight = 'bold',color='black');
plt.savefig("notebook products.jpg")
plt.axes().set(facecolor = "White")
plt.show();
# Out:
# <ipython-input-27-2549245692d0>:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %% [markdown]
# ## Data for corr

# %%
df1 = pd.read_csv("/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/kaggle_survey_2021_responses.csv")
# Out:
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df1.drop(df1.index[0],inplace=True)

# %%
df1
# Out:
#       Time from Start to Finish (seconds)     Q1   Q2  \
# 1                                     910  50-54  Man
# 2                                     784  50-54  Man
# 3                                     924  22-24  Man
# 4                                     575  45-49  Man
# 5                                     781  45-49  Man
# ...                                   ...    ...  ...
# 25969                                1756  30-34  Man
# 25970                                 253  22-24  Man
# 25971                                 494  50-54  Man
# 25972                                 277  45-49  Man
# 25973                                 255  18-21  Man
#
#                              Q3                 Q4                       Q5  \
# 1                         India  Bachelor’s degree                    Other
# 2                     Indonesia    Master’s degree  Program/Project Manager
# 3                      Pakistan    Master’s degree        Software Engineer
# 4                        Mexico    Doctoral degree       Research Scientist
# 5                         India    Doctoral degree                    Other
# ...                         ...                ...                      ...
# 25969                     Egypt  Bachelor’s degree             Data Analyst
# 25970                     China    Master’s degree                  Student
# 25971                    Sweden    Doctoral degree       Research Scientist
# 25972  United States of America    Master’s degree           Data Scientist
# 25973                     India  Bachelor’s degree         Business Analyst
#
#                               Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 1                     5-10 years    Python         R       NaN  ...
# 2                      20+ years       NaN       NaN       SQL  ...
# 3                      1-3 years    Python       NaN       NaN  ...
# 4                      20+ years    Python       NaN       NaN  ...
# 5                      < 1 years    Python       NaN       NaN  ...
# ...                          ...       ...       ...       ...  ...
# 25969                  1-3 years    Python       NaN       SQL  ...
# 25970                  1-3 years    Python       NaN       NaN  ...
# 25971  I have never written code       NaN       NaN       NaN  ...
# 25972                 5-10 years    Python       NaN       SQL  ...
# 25973  I have never written code       NaN       NaN       NaN  ...
#
#       Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7  \
# 1              NaN          NaN            NaN          NaN          NaN
# 2              NaN          NaN            NaN          NaN          NaN
# 3              NaN          NaN   TensorBoard           NaN          NaN
# 4              NaN          NaN            NaN          NaN          NaN
# 5              NaN          NaN            NaN          NaN          NaN
# ...            ...          ...            ...          ...          ...
# 25969          NaN          NaN            NaN          NaN          NaN
# 25970          NaN          NaN            NaN          NaN          NaN
# 25971          NaN          NaN            NaN          NaN          NaN
# 25972          NaN          NaN            NaN          NaN          NaN
# 25973          NaN          NaN            NaN          NaN          NaN
#
#       Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 1              NaN          NaN           NaN           NaN         NaN
# 2              NaN          NaN           NaN          None         NaN
# 3              NaN          NaN           NaN           NaN         NaN
# 4              NaN          NaN           NaN          None         NaN
# 5              NaN          NaN           NaN           NaN         NaN
# ...            ...          ...           ...           ...         ...
# 25969          NaN          NaN           NaN           NaN         NaN
# 25970          NaN          NaN           NaN           NaN         NaN
# 25971          NaN          NaN           NaN          None         NaN
# 25972          NaN          NaN           NaN           NaN         NaN
# 25973          NaN          NaN           NaN          None         NaN
#
# [25973 rows x 369 columns]

# %%
dc = { "$0-999"      :1,
"1,000-1,999"        :2,
"10,000-14,999"      :3,
"30,000-39,999"      :4,
"100,000-124,999"    :5,
"5,000-7,499"        :6,
"50,000-59,999"      :7,
"40,000-49,999"      :8,
"20,000-24,999"      :9,
"15,000-19,999"      :10,
"2,000-2,999"        :11,
"60,000-69,999"      :12,
"7,500-9,999"        :13,
"25,000-29,999"      :14,
"70,000-79,999"      :15,
"4,000-4,999"        :16,
"80,000-89,999"      :17,
"150,000-199,999"    :18,
"3,000-3,999"        :19,
"125,000-149,999"    :20,
"90,000-99,999"      :21,
"200,000-249,999"    :22,
"300,000-499,999"    :23,
"250,000-299,999"    :24,
">$1,000,000"        :25,
"$500,000-999,999"  :26,
     }

# %%
dy = { "1-3 years"          :1,
"< 1 years"                 :2,
"3-5 years"                 :3,
"5-10 years"                :4,
"10-20 years"               :5,
"20+ years"                 :6,
"I have never written code" :7,
     }

# %%
df1.replace({"Q25": dc ,"Q6":dy},inplace=True)

# %%
df1.dropna(subset=["Q25"],inplace=True)

# %% [markdown]
# # Correlation between experience and salary

# %%
np.corrcoef(df1["Q25"],df1["Q6"])
# Out:
# array([[1.        , 0.19242594],
#        [0.19242594, 1.        ]])

# %% [markdown]
# # Compare 3 years

# %%
survey19 = pd.read_csv('/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/multiple_choice_responses.csv')
survey20 = pd.read_csv('/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/kaggle_survey_2020_responses.csv')
survey21 = pd.read_csv('/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/kaggle_survey_2021_responses.csv')
# Out:
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,3,7,19,34,47,49,50,51,52,53,54,68,81,94,96,109,115,130,139,147,154,167,180,193,206,219,232,245) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#2021

Q7_21 = [col for col in survey21 if col.startswith('Q7')]
survey21_Q7 = survey21[Q7_21] 
survey21_Q7 

survey21_Q7.columns = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 'Javascript', 'Julia', 'Swift', 'Bash', 'MATLAB', 'None', 'Other']

survey21_Q7.drop(survey21_Q7.index[0],inplace=True)

survey21_Q7["Year"] =  2021
# Out:
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-37-cc9b2a886131>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey21_Q7["Year"] =  2021

# %%
#2020 

Q7_20 = [col for col in survey20 if col.startswith('Q7')]
survey20_Q7 = survey20[Q7_20] 
survey20_Q7 

survey20_Q7.columns = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 'Javascript', 'Julia', 'Swift', 'Bash', 'MATLAB', 'None', 'Other']

survey20_Q7.drop(survey20_Q7.index[0],inplace=True)

survey20_Q7["Year"] =  2020
# Out:
# <ipython-input-38-5912c1ae9a93>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey20_Q7["Year"] =  2020

# %%
#2020 

Q7_19 = [col for col in survey19 if col.startswith('Q18')]
survey19_Q7 = survey19[Q7_19] 
survey19_Q7 

survey19_Q7.columns = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 'Javascript', 'Julia', 'Swift', 'Bash', 'MATLAB', 'None', 'Other']

survey19_Q7.drop(survey19_Q7.index[0],inplace=True)
sns.color_palette("viridis")
survey19_Q7["Year"] =  2019
# Out:
# <ipython-input-39-a7564418f112>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey19_Q7["Year"] =  2019

# %%
dfs = [survey21_Q7, survey20_Q7, survey19_Q7]
dfs_ = pd.concat(dfs)
dfs__ = dfs_.iloc[:, : 11]

# %%
dfs_
# Out:
#        Python    R  SQL    C  C++  Java Javascript Julia Swift Bash  MATLAB  \
# 1      Python    R  NaN  NaN  NaN   NaN        NaN   NaN   NaN  NaN     NaN
# 2         NaN  NaN  SQL    C  C++  Java        NaN   NaN   NaN  NaN     NaN
# 3      Python  NaN  NaN  NaN  C++  Java        NaN   NaN   NaN  NaN     NaN
# 4      Python  NaN  NaN  NaN  NaN   NaN        NaN   NaN   NaN  NaN     NaN
# 5      Python  NaN  NaN    C  NaN   NaN        NaN   NaN   NaN  NaN  MATLAB
# ...       ...  ...  ...  ...  ...   ...        ...   ...   ...  ...     ...
# 19713     NaN  NaN  NaN  NaN  NaN   NaN        NaN   NaN   NaN  NaN     NaN
# 19714     NaN  NaN  NaN  NaN  NaN   NaN        NaN   NaN   NaN  NaN     NaN
# 19715     NaN  NaN  NaN  NaN  NaN   NaN        NaN   NaN   NaN  NaN     NaN
# 19716     NaN  NaN  NaN  NaN  NaN   NaN        NaN   NaN   NaN  NaN     NaN
# 19717  Python  NaN  SQL  NaN  NaN  Java        NaN   NaN  Bash  NaN     NaN
#
#       None Other  Year
# 1      NaN   NaN  2021
# 2      NaN   NaN  2021
# 3      NaN   NaN  2021
# 4      NaN   NaN  2021
# 5      NaN   NaN  2021
# ...    ...   ...   ...
# 19713  NaN    -1  2019
# 19714  NaN    -1  2019
# 19715  NaN    -1  2019
# 19716  NaN    -1  2019
# 19717  NaN    -1  2019
#
# [65726 rows x 14 columns]

# %%
plt.figure(figsize=(5, 5))
sns.countplot(data=dfs_, x=dfs_["Python"],hue=dfs_['Year'],order=dfs_["Python"].value_counts().index,palette= 'viridis')
sns.despine()
plt.axes().set(facecolor = "White")
plt.title('')
plt.xlabel('')
plt.ylabel('')
plt.show()
# Out:
# <ipython-input-42-1832bad44ff2>:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")

# %% [markdown]
# # Compare 3 years

# %%
#2021
Q7_2021 = [col for col in survey21 if col.startswith('Q7')]
Q7_2021

df7_2021 = survey21[Q7_2021]
Q2021 = list(df7_2021.count())

# %%
#2020
Q7_2020 = [col for col in survey20 if col.startswith('Q7')]
Q7_2020

df7_2020 = survey20[Q7_2020]
Q2020 = list(df7_2020.count())

# %%
#2019
Q7_2019 = [col for col in survey19 if col.startswith('Q18')]
Q7_2019

df7_2019 = survey19[Q7_2019]
Q2019 = list(df7_2019.count())

# %%
plotdata = pd.DataFrame({
    "2019":Q2019[0:11],    
    "2020":Q2020[0:11],
    "2021":Q2021[0:11]
    }, 
    index= ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 'Javascript', 'Julia', 'Swift', 'Bash', 'MATLAB']
).sort_values(by='2021', ascending=False)

plotdata.plot(kind="bar", color=["dodgerblue", "mediumturquoise","silver"],figsize=(10,6))

plt.xlabel("programming languages",fontsize = 10, weight = 'bold',color='black')
plt.title("Most used programming languages 2019-2021",fontsize = 20, weight = 'bold',color='black')
plt.axes().set(facecolor = "White")
# Out:
# <ipython-input-46-480d73329637>:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set(facecolor = "White")
# [None]

# %%
plotdata
# Out:
#              2019   2020   2021
# Python      12842  15531  21861
# SQL          6533   7536  10757
# C++          2257   3828   5536
# R            4589   4278   5335
# Java         2268   3368   4770
# C            1673   3316   4710
# Javascript   2175   2996   4333
# MATLAB         84   2218   2936
# Bash         1517   1777   2217
# Julia         390    263    306
# Swift        2038    199    243
