# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = "svg"

# %%
df = pd.read_csv("/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/kaggle_survey_2021_responses.csv")
# Out:
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning:
#
# Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
len(df.columns)
# Out:
# 369

# %%
df["Q6"].isnull().sum()
# Out:
# 0

# %%
df["Q25"].isnull().sum()
# Out:
# 10582

# %%
df.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 910                        50-54
# 2                                 784                        50-54
# 3                                 924                        22-24
# 4                                 575                        45-49
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                  Indonesia
# 3                                   Pakistan
# 4                                     Mexico
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                  Bachelor’s degree
# 2                                    Master’s degree
# 3                                    Master’s degree
# 4                                    Doctoral degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                              Other
# 2                            Program/Project Manager
# 3                                  Software Engineer
# 4                                 Research Scientist
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                                         5-10 years
# 2                                          20+ years
# 3                                          1-3 years
# 4                                          20+ years
#
#                                            Q7_Part_1  \
# 0  What programming languages do you use on a reg...
# 1                                             Python
# 2                                                NaN
# 3                                             Python
# 4                                             Python
#
#                                            Q7_Part_2  \
# 0  What programming languages do you use on a reg...
# 1                                                  R
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_3  ...  \
# 0  What programming languages do you use on a reg...  ...
# 1                                                NaN  ...
# 2                                                SQL  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#                                         Q38_B_Part_3  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_4  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_5  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                       TensorBoard
# 4                                                NaN
#
#                                         Q38_B_Part_6  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_7  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_8  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_9  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q38_B_Part_10  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q38_B_Part_11  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                               None
# 3                                                NaN
# 4                                               None
#
#                                          Q38_B_OTHER
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 369 columns]

# %%
df.tail()
# Out:
#       Time from Start to Finish (seconds)     Q1   Q2  \
# 25969                                1756  30-34  Man
# 25970                                 253  22-24  Man
# 25971                                 494  50-54  Man
# 25972                                 277  45-49  Man
# 25973                                 255  18-21  Man
#
#                              Q3                 Q4                  Q5  \
# 25969                     Egypt  Bachelor’s degree        Data Analyst
# 25970                     China    Master’s degree             Student
# 25971                    Sweden    Doctoral degree  Research Scientist
# 25972  United States of America    Master’s degree      Data Scientist
# 25973                     India  Bachelor’s degree    Business Analyst
#
#                               Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 25969                  1-3 years    Python       NaN       SQL  ...
# 25970                  1-3 years    Python       NaN       NaN  ...
# 25971  I have never written code       NaN       NaN       NaN  ...
# 25972                 5-10 years    Python       NaN       SQL  ...
# 25973  I have never written code       NaN       NaN       NaN  ...
#
#       Q38_B_Part_3 Q38_B_Part_4 Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7  \
# 25969          NaN          NaN          NaN          NaN          NaN
# 25970          NaN          NaN          NaN          NaN          NaN
# 25971          NaN          NaN          NaN          NaN          NaN
# 25972          NaN          NaN          NaN          NaN          NaN
# 25973          NaN          NaN          NaN          NaN          NaN
#
#       Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 25969          NaN          NaN           NaN           NaN         NaN
# 25970          NaN          NaN           NaN           NaN         NaN
# 25971          NaN          NaN           NaN          None         NaN
# 25972          NaN          NaN           NaN           NaN         NaN
# 25973          NaN          NaN           NaN          None         NaN
#
# [5 rows x 369 columns]

# %%
df.describe()
# Out:
#         Time from Start to Finish (seconds)     Q1     Q2     Q3  \
# count                                 25974  25974  25974  25974
# unique                                 5410     12      6     67
# top                                     484  25-29    Man  India
# freq                                     42   4931  20598   7434
#
#                      Q4       Q5         Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# count             25974    25974      25974     21861      5335     10757
# unique                8       16          8         2         2         2
# top     Master’s degree  Student  1-3 years    Python         R       SQL
# freq              10132     6804       7874     21860      5334     10756
#
#         ... Q38_B_Part_3          Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6  \
# count   ...          634                   592           4240          730
# unique  ...            2                     2              2            2
# top     ...    Comet.ml    Sacred + Omniboard    TensorBoard     Guild.ai
# freq    ...          633                   591           4239          729
#
#        Q38_B_Part_7 Q38_B_Part_8            Q38_B_Part_9 Q38_B_Part_10  \
# count           738         1021                     667          2748
# unique            2            2                       2             2
# top       Polyaxon      ClearML    Domino Model Monitor        MLflow
# freq            737         1020                     666          2747
#
#        Q38_B_Part_11 Q38_B_OTHER
# count           4543         378
# unique             2           2
# top             None       Other
# freq            4542         377
#
# [4 rows x 369 columns]

# %%
df.drop(df.index[0],inplace=True)

# %%
df["Q2"].unique()
# Out:
# array(['Man', 'Woman', 'Nonbinary', 'Prefer not to say',
#        'Prefer to self-describe'], dtype=object)

# %%
df.drop(df[df["Q2"].isin(['Nonbinary', 'Prefer not to say', 'Prefer to self-describe'])].index, inplace=True)

# %% [markdown]
# # Gender

# %%
plt.figure(figsize = (8,5))
labels= ['Man','Woman']
sns.set(style='darkgrid')
colors = ['lightskyblue', 'magenta']
gender = df['Q2'].value_counts()
plt.pie(gender,colors = colors, autopct='%1.1f%%', shadow=True,radius = 1.5,pctdistance = 1.2)
plt.legend(labels,loc = 'best')
plt.show()

# %% [markdown]
# ## Let's see the questions answered by 50% of the Kaggle community

# %%
n = []
for i in df:
    if df[i].isnull().sum() > 25974/2:   #25974 in number of Respondents 
        n.append(i)

# %%
df1 = df.drop(n,axis = 1)
df1.drop(df1.index[0],inplace=True)

# %%
df1
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 2                                     784  50-54    Man
# 3                                     924  22-24    Man
# 4                                     575  45-49    Man
# 5                                     781  45-49    Man
# 6                                    1020  25-29  Woman
# ...                                   ...    ...    ...
# 25969                                1756  30-34    Man
# 25970                                 253  22-24    Man
# 25971                                 494  50-54    Man
# 25972                                 277  45-49    Man
# 25973                                 255  18-21    Man
#
#                              Q3                      Q4  \
# 2                     Indonesia         Master’s degree
# 3                      Pakistan         Master’s degree
# 4                        Mexico         Doctoral degree
# 5                         India         Doctoral degree
# 6                         India  I prefer not to answer
# ...                         ...                     ...
# 25969                     Egypt       Bachelor’s degree
# 25970                     China         Master’s degree
# 25971                    Sweden         Doctoral degree
# 25972  United States of America         Master’s degree
# 25973                     India       Bachelor’s degree
#
#                             Q5                         Q6 Q7_Part_1      Q8  \
# 2      Program/Project Manager                  20+ years       NaN  Python
# 3            Software Engineer                  1-3 years    Python  Python
# 4           Research Scientist                  20+ years    Python  Python
# 5                        Other                  < 1 years    Python  Python
# 6       Currently not employed                  < 1 years    Python  Python
# ...                        ...                        ...       ...     ...
# 25969             Data Analyst                  1-3 years    Python  Python
# 25970                  Student                  1-3 years    Python  Python
# 25971       Research Scientist  I have never written code       NaN     NaN
# 25972           Data Scientist                 5-10 years    Python  Python
# 25973         Business Analyst  I have never written code       NaN     NaN
#
#               Q9_Part_11  ...                                    Q15  \
# 2       Jupyter Notebook  ...                           Under 1 year
# 3       Jupyter Notebook  ...  I do not use machine learning methods
# 4       Jupyter Notebook  ...                             5-10 years
# 5       Jupyter Notebook  ...                            10-20 years
# 6       Jupyter Notebook  ...                           Under 1 year
# ...                  ...  ...                                    ...
# 25969   Jupyter Notebook  ...                              1-2 years
# 25970                NaN  ...                              1-2 years
# 25971                NaN  ...                                    NaN
# 25972   Jupyter Notebook  ...                              4-5 years
# 25973                NaN  ...                                    NaN
#
#             Q16_Part_1                     Q17_Part_1  \
# 2        Scikit-learn   Linear or Logistic Regression
# 3                  NaN                            NaN
# 4        Scikit-learn                             NaN
# 5        Scikit-learn   Linear or Logistic Regression
# 6        Scikit-learn   Linear or Logistic Regression
# ...                ...                            ...
# 25969    Scikit-learn   Linear or Logistic Regression
# 25970              NaN                            NaN
# 25971              NaN                            NaN
# 25972    Scikit-learn   Linear or Logistic Regression
# 25973              NaN                            NaN
#
#                                           Q20                       Q21  Q22  \
# 2                   Manufacturing/Fabrication      1000-9,999 employees  1-2
# 3                         Academics/Education      1000-9,999 employees    0
# 4                         Academics/Education      1000-9,999 employees    0
# 5                         Academics/Education          50-249 employees  5-9
# 6                                         NaN                       NaN  NaN
# ...                                       ...                       ...  ...
# 25969                    Computers/Technology  10,000 or more employees  20+
# 25970                                     NaN                       NaN  NaN
# 25971                     Academics/Education      1000-9,999 employees  20+
# 25972  Online Service/Internet-based Services  10,000 or more employees  20+
# 25973                                   Other            0-49 employees    0
#
#                                                      Q23            Q25  \
# 2      We are exploring ML methods (and may one day p...  60,000-69,999
# 3                                          I do not know         $0-999
# 4                                          I do not know  30,000-39,999
# 5      We use ML methods for generating insights (but...  30,000-39,999
# 6                                                    NaN            NaN
# ...                                                  ...            ...
# 25969  We are exploring ML methods (and may one day p...  15,000-19,999
# 25970                                                NaN            NaN
# 25971                                      I do not know         $0-999
# 25972  We have well established ML methods (i.e., mod...            NaN
# 25973                                      I do not know         $0-999
#
#                 Q26                                                Q41
# 2         $0 ($USD)    Advanced statistical software (SPSS, SAS, etc.)
# 3         $0 ($USD)  Basic statistical software (Microsoft Excel, G...
# 4         $0 ($USD)  Local development environments (RStudio, Jupyt...
# 5      $1000-$9,999  Local development environments (RStudio, Jupyt...
# 6               NaN  Local development environments (RStudio, Jupyt...
# ...             ...                                                ...
# 25969  $1000-$9,999  Business intelligence software (Salesforce, Ta...
# 25970           NaN                                                NaN
# 25971        $1-$99  Basic statistical software (Microsoft Excel, G...
# 25972           NaN                                                NaN
# 25973     $0 ($USD)    Advanced statistical software (SPSS, SAS, etc.)
#
# [25487 rows x 24 columns]

# %%
df1.isna().sum()
# Out:
# Time from Start to Finish (seconds)        0
# Q1                                         0
# Q2                                         0
# Q3                                         0
# Q4                                         0
# Q5                                         0
# Q6                                         0
# Q7_Part_1                               4029
# Q8                                      1016
# Q9_Part_11                              9532
# Q11                                     1232
# Q12_Part_5                             12495
# Q13                                     1541
# Q14_Part_1                              8187
# Q15                                     2181
# Q16_Part_1                             11731
# Q17_Part_1                             11870
# Q20                                     9450
# Q21                                     9524
# Q22                                     9645
# Q23                                     9816
# Q25                                    10364
# Q26                                    10569
# Q41                                     7341
# dtype: int64

# %% [markdown]
# # Age

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
sns.countplot(y = 'Q1',data = df1,order = df1['Q1'].value_counts().index)
plt.ylabel('Age Groub',fontsize = 20, weight = 'bold',color='green');
plt.show()

# %% [markdown]
# # Job

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
sns.countplot(y = 'Q5',
              data = df1,
              order = df1['Q5'].value_counts().index)
plt.xticks(size = 12)
plt.ylabel('Job',fontsize = 20, weight = 'bold',color='green');
plt.show()

# %% [markdown]
# # Education

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
sns.countplot(y = 'Q4',
              data = df1,
              order = df1['Q4'].value_counts().index)
plt.ylabel('Education',fontsize = 20, weight = 'bold',color='green');
plt.show()

# %% [markdown]
# # Experience

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
sns.countplot(y = 'Q6',
              data = df1,
              order = df1['Q6'].value_counts().index)
plt.xticks(size = 12)
plt.ylabel('Years of Experience',fontsize = 20, weight = 'bold',color='green');
plt.show()

# %% [markdown]
# # Salary

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
sns.countplot(y = 'Q25',
              data = df1,
              order = df1['Q25'].value_counts().index)
plt.xticks(size = 12)
plt.ylabel('Salary',fontsize = 20, weight = 'bold',color='green');
plt.show()

# %% [markdown]
# # Country

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,15))
sns.countplot(y = 'Q3',
              data = df1,
              order = df1['Q3'].value_counts().index)
plt.ylabel('Country',fontsize = 20, weight = 'bold',color='green');
plt.show()

# %% [markdown]
# ### Since some questions are branched, we will use the original data without deleting any columns.

# %%
df2 = pd.read_csv("/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/kaggle_survey_2021_responses.csv",header=None)
# Out:
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning:
#
# Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df2
# Out:
#                                        0                            1    \
# 0      Time from Start to Finish (seconds)                           Q1
# 1                    Duration (in seconds)  What is your age (# years)?
# 2                                      910                        50-54
# 3                                      784                        50-54
# 4                                      924                        22-24
# ...                                    ...                          ...
# 25970                                 1756                        30-34
# 25971                                  253                        22-24
# 25972                                  494                        50-54
# 25973                                  277                        45-49
# 25974                                  255                        18-21
#
#                                           2    \
# 0                                          Q2
# 1      What is your gender? - Selected Choice
# 2                                         Man
# 3                                         Man
# 4                                         Man
# ...                                       ...
# 25970                                     Man
# 25971                                     Man
# 25972                                     Man
# 25973                                     Man
# 25974                                     Man
#
#                                              3    \
# 0                                             Q3
# 1      In which country do you currently reside?
# 2                                          India
# 3                                      Indonesia
# 4                                       Pakistan
# ...                                          ...
# 25970                                      Egypt
# 25971                                      China
# 25972                                     Sweden
# 25973                   United States of America
# 25974                                      India
#
#                                                      4    \
# 0                                                     Q4
# 1      What is the highest level of formal education ...
# 2                                      Bachelor’s degree
# 3                                        Master’s degree
# 4                                        Master’s degree
# ...                                                  ...
# 25970                                  Bachelor’s degree
# 25971                                    Master’s degree
# 25972                                    Doctoral degree
# 25973                                    Master’s degree
# 25974                                  Bachelor’s degree
#
#                                                      5    \
# 0                                                     Q5
# 1      Select the title most similar to your current ...
# 2                                                  Other
# 3                                Program/Project Manager
# 4                                      Software Engineer
# ...                                                  ...
# 25970                                       Data Analyst
# 25971                                            Student
# 25972                                 Research Scientist
# 25973                                     Data Scientist
# 25974                                   Business Analyst
#
#                                                      6    \
# 0                                                     Q6
# 1      For how many years have you been writing code ...
# 2                                             5-10 years
# 3                                              20+ years
# 4                                              1-3 years
# ...                                                  ...
# 25970                                          1-3 years
# 25971                                          1-3 years
# 25972                          I have never written code
# 25973                                         5-10 years
# 25974                          I have never written code
#
#                                                      7    \
# 0                                              Q7_Part_1
# 1      What programming languages do you use on a reg...
# 2                                                 Python
# 3                                                    NaN
# 4                                                 Python
# ...                                                  ...
# 25970                                             Python
# 25971                                             Python
# 25972                                                NaN
# 25973                                             Python
# 25974                                                NaN
#
#                                                      8    \
# 0                                              Q7_Part_2
# 1      What programming languages do you use on a reg...
# 2                                                      R
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
# 25974                                                NaN
#
#                                                      9    ...  \
# 0                                              Q7_Part_3  ...
# 1      What programming languages do you use on a reg...  ...
# 2                                                    NaN  ...
# 3                                                    SQL  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 25970                                                SQL  ...
# 25971                                                NaN  ...
# 25972                                                NaN  ...
# 25973                                                SQL  ...
# 25974                                                NaN  ...
#
#                                                      359  \
# 0                                           Q38_B_Part_3
# 1      In the next 2 years, do you hope to become mor...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
# 25974                                                NaN
#
#                                                      360  \
# 0                                           Q38_B_Part_4
# 1      In the next 2 years, do you hope to become mor...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
# 25974                                                NaN
#
#                                                      361  \
# 0                                           Q38_B_Part_5
# 1      In the next 2 years, do you hope to become mor...
# 2                                                    NaN
# 3                                                    NaN
# 4                                           TensorBoard
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
# 25974                                                NaN
#
#                                                      362  \
# 0                                           Q38_B_Part_6
# 1      In the next 2 years, do you hope to become mor...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
# 25974                                                NaN
#
#                                                      363  \
# 0                                           Q38_B_Part_7
# 1      In the next 2 years, do you hope to become mor...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
# 25974                                                NaN
#
#                                                      364  \
# 0                                           Q38_B_Part_8
# 1      In the next 2 years, do you hope to become mor...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
# 25974                                                NaN
#
#                                                      365  \
# 0                                           Q38_B_Part_9
# 1      In the next 2 years, do you hope to become mor...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
# 25974                                                NaN
#
#                                                      366  \
# 0                                          Q38_B_Part_10
# 1      In the next 2 years, do you hope to become mor...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
# 25974                                                NaN
#
#                                                      367  \
# 0                                          Q38_B_Part_11
# 1      In the next 2 years, do you hope to become mor...
# 2                                                    NaN
# 3                                                   None
# 4                                                    NaN
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                               None
# 25973                                                NaN
# 25974                                               None
#
#                                                      368
# 0                                            Q38_B_OTHER
# 1      In the next 2 years, do you hope to become mor...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
# 25973                                                NaN
# 25974                                                NaN
#
# [25975 rows x 369 columns]

# %%
Q7 = list(df2.loc[0][7:20])
Q7
df7 = df[Q7]
# Out:
# ['Q7_Part_1',
#  'Q7_Part_2',
#  'Q7_Part_3',
#  'Q7_Part_4',
#  'Q7_Part_5',
#  'Q7_Part_6',
#  'Q7_Part_7',
#  'Q7_Part_8',
#  'Q7_Part_9',
#  'Q7_Part_10',
#  'Q7_Part_11',
#  'Q7_Part_12',
#  'Q7_OTHER']

# %% [markdown]
# ## Most used programming languages for 2021

# %%
df7 = df[Q7]

df7.columns = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 'Javascript', 'Julia', 'Swift', 'Bash', 'MATLAB', 'None', 'Other']

plt.figure(figsize=(10,10))
df7.count().sort_values(ascending=True).plot(kind = 'pie');
plt.ylabel('Most used programming languages for 2021',fontsize = 20, weight = 'bold',color='green');
plt.show();

# %%
df7.count()
# Out:
# Python        21459
# R              5217
# SQL           10550
# C              4624
# C++            5437
# Java           4666
# Javascript     4240
# Julia           292
# Swift           230
# Bash           2129
# MATLAB         2880
# None            308
# Other          2508
# dtype: int64

# %%
plt.figure(figsize = (8,8))
df7.columns = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 'Javascript', 'Julia', 'Swift', 'Bash', 'MATLAB', 'None', 'Other']
df77 = df7.count()
sns.set(style='darkgrid')
plt.pie(df77, autopct='%1.1f%%', shadow=True,radius = 1.5,pctdistance = 1.2)
plt.legend( df7.columns ,loc = 'best')
plt.show()
df77
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-effc7edab27c> in <module>
#       3 df77 = df7.count()
#       4 sns.set(style='darkgrid')
# ----> 5 plt.bar(df77, autopct='%1.1f%%', shadow=True,radius = 1.5,pctdistance = 1.2)
#       6 plt.legend( df7.columns ,loc = 'best')
#       7 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %% [markdown]
# ## Most used of (IDE's) in 2021

# %%
Q9 = list(df2.loc[0][21:34])
df9 = df[Q9]

df9.columns = ['Jupyter (JupyterLab, Jupyter Notebooks, etc)',' RStudio','Visual Studio','Visual Studio Code (VSCode)',
              'PyCharm','Spyder','Notepad++','Sublime Text','Vim / Emacs','MATLAB','Jupyter Notebook','None','Other']

plt.figure(figsize=(10,10))
df9.count().sort_values(ascending=False).plot(kind = 'bar');
plt.ylabel("Most used (IDE's) for 2021",fontsize = 20, weight = 'bold',color='green');
plt.show();

# %%
Q10 = list(df2.loc[0][34:51])
df10 = df[Q10]

df10.columns = ['Kaggle Notebooks','Colab Notebooks','Azure Notebooks','Paperspace / Gradient','Binder / JupyterHub','Code Ocean','IBM Watson Studio',
              'Amazon Sagemaker Studio Notebooks','Amazon EMR Notebooks','Google Cloud Notebooks (AI Platform / Vertex AI)','Google Cloud Datalab',
              'Databricks Collaborative Notebooks','Zeppelin / Zepl Notebooks','Deepnote Notebooks','Observable Notebooks','None','Other']

plt.figure(figsize=(20,10))
df10.count().sort_values(ascending=True).plot(kind = 'barh');
plt.show();

# %%
df3.drop(df3.index[0],inplace=True)

# %%
df3
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 2                                     784  50-54    Man
# 3                                     924  22-24    Man
# 4                                     575  45-49    Man
# 5                                     781  45-49    Man
# 6                                    1020  25-29  Woman
# ...                                   ...    ...    ...
# 25969                                1756  30-34    Man
# 25970                                 253  22-24    Man
# 25971                                 494  50-54    Man
# 25972                                 277  45-49    Man
# 25973                                 255  18-21    Man
#
#                              Q3                      Q4  \
# 2                     Indonesia         Master’s degree
# 3                      Pakistan         Master’s degree
# 4                        Mexico         Doctoral degree
# 5                         India         Doctoral degree
# 6                         India  I prefer not to answer
# ...                         ...                     ...
# 25969                     Egypt       Bachelor’s degree
# 25970                     China         Master’s degree
# 25971                    Sweden         Doctoral degree
# 25972  United States of America         Master’s degree
# 25973                     India       Bachelor’s degree
#
#                             Q5                         Q6 Q7_Part_1 Q7_Part_2  \
# 2      Program/Project Manager                  20+ years       NaN       NaN
# 3            Software Engineer                  1-3 years    Python       NaN
# 4           Research Scientist                  20+ years    Python       NaN
# 5                        Other                  < 1 years    Python       NaN
# 6       Currently not employed                  < 1 years    Python       NaN
# ...                        ...                        ...       ...       ...
# 25969             Data Analyst                  1-3 years    Python       NaN
# 25970                  Student                  1-3 years    Python       NaN
# 25971       Research Scientist  I have never written code       NaN       NaN
# 25972           Data Scientist                 5-10 years    Python       NaN
# 25973         Business Analyst  I have never written code       NaN       NaN
#
#       Q7_Part_3  ... Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6  \
# 2           SQL  ...          NaN          NaN            NaN          NaN
# 3           NaN  ...          NaN          NaN   TensorBoard           NaN
# 4           NaN  ...          NaN          NaN            NaN          NaN
# 5           NaN  ...          NaN          NaN            NaN          NaN
# 6           NaN  ...          NaN          NaN            NaN    Guild.ai
# ...         ...  ...          ...          ...            ...          ...
# 25969       SQL  ...          NaN          NaN            NaN          NaN
# 25970       NaN  ...          NaN          NaN            NaN          NaN
# 25971       NaN  ...          NaN          NaN            NaN          NaN
# 25972       SQL  ...          NaN          NaN            NaN          NaN
# 25973       NaN  ...          NaN          NaN            NaN          NaN
#
#       Q38_B_Part_7 Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11  \
# 2              NaN          NaN          NaN           NaN          None
# 3              NaN          NaN          NaN           NaN           NaN
# 4              NaN          NaN          NaN           NaN          None
# 5              NaN          NaN          NaN           NaN           NaN
# 6              NaN          NaN          NaN       MLflow            NaN
# ...            ...          ...          ...           ...           ...
# 25969          NaN          NaN          NaN           NaN           NaN
# 25970          NaN          NaN          NaN           NaN           NaN
# 25971          NaN          NaN          NaN           NaN          None
# 25972          NaN          NaN          NaN           NaN           NaN
# 25973          NaN          NaN          NaN           NaN          None
#
#       Q38_B_OTHER
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# ...           ...
# 25969         NaN
# 25970         NaN
# 25971         NaN
# 25972         NaN
# 25973         NaN
#
# [25972 rows x 369 columns]

# %%
df3["Q25"].value_counts()
# Out:
# $0-999              3369
# 1,000-1,999          969
# 10,000-14,999        950
# 30,000-39,999        741
# 100,000-124,999      725
# 5,000-7,499          699
# 50,000-59,999        697
# 40,000-49,999        688
# 20,000-24,999        587
# 2,000-2,999          575
# 15,000-19,999        573
# 7,500-9,999          552
# 60,000-69,999        551
# 25,000-29,999        469
# 70,000-79,999        464
# 4,000-4,999          456
# 150,000-199,999      392
# 80,000-89,999        391
# 3,000-3,999          380
# 125,000-149,999      379
# 90,000-99,999        350
# 200,000-249,999      177
# 300,000-499,999       91
# 250,000-299,999       75
# >$1,000,000           58
# $500,000-999,999      32
# Name: Q25, dtype: int64

# %%
dc = { "$0-999"      :1,
"1,000-1,999"        :2,
"10,000-14,999"      :3,
"30,000-39,999"      :4,
"100,000-124,999"    :5,
"5,000-7,499"        :6,
"50,000-59,999"      :7,
"40,000-49,999"      :8,
"20,000-24,999"      :9,
"15,000-19,999"      :10,
"2,000-2,999"        :11,
"60,000-69,999"      :12,
"7,500-9,999"        :13,
"25,000-29,999"      :14,
"70,000-79,999"      :15,
"4,000-4,999"        :16,
"80,000-89,999"      :17,
"150,000-199,999"    :18,
"3,000-3,999"        :19,
"125,000-149,999"    :20,
"90,000-99,999"      :21,
"200,000-249,999"    :22,
"300,000-499,999"    :23,
"250,000-299,999"    :24,
">$1,000,000"        :25,
"$500,000-999,999"  :26,
     }

# %%
dy = { "1-3 years"          :1,
"< 1 years"                 :2,
"3-5 years"                 :3,
"5-10 years"                :4,
"10-20 years"               :5,
"20+ years"                 :6,
"I have never written code" :7,
     }

# %%
df_r=df3.replace({"Q25": dc ,"Q6":dy})

# %%
df_r["Q25"].dtype
# Out:
# dtype('float64')

# %%
df_r["Q25"].corr
# Out:
# <bound method Series.corr of 2        12.0
# 3         1.0
# 4         4.0
# 5         4.0
# 6         NaN
#          ...
# 25969    10.0
# 25970     NaN
# 25971     1.0
# 25972     NaN
# 25973     1.0
# Name: Q25, Length: 25972, dtype: float64>

# %%
df_r
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 2                                     784  50-54    Man
# 3                                     924  22-24    Man
# 4                                     575  45-49    Man
# 5                                     781  45-49    Man
# 6                                    1020  25-29  Woman
# ...                                   ...    ...    ...
# 25969                                1756  30-34    Man
# 25970                                 253  22-24    Man
# 25971                                 494  50-54    Man
# 25972                                 277  45-49    Man
# 25973                                 255  18-21    Man
#
#                              Q3                      Q4  \
# 2                     Indonesia         Master’s degree
# 3                      Pakistan         Master’s degree
# 4                        Mexico         Doctoral degree
# 5                         India         Doctoral degree
# 6                         India  I prefer not to answer
# ...                         ...                     ...
# 25969                     Egypt       Bachelor’s degree
# 25970                     China         Master’s degree
# 25971                    Sweden         Doctoral degree
# 25972  United States of America         Master’s degree
# 25973                     India       Bachelor’s degree
#
#                             Q5  Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 2      Program/Project Manager   6       NaN       NaN       SQL  ...
# 3            Software Engineer   1    Python       NaN       NaN  ...
# 4           Research Scientist   6    Python       NaN       NaN  ...
# 5                        Other   2    Python       NaN       NaN  ...
# 6       Currently not employed   2    Python       NaN       NaN  ...
# ...                        ...  ..       ...       ...       ...  ...
# 25969             Data Analyst   1    Python       NaN       SQL  ...
# 25970                  Student   1    Python       NaN       NaN  ...
# 25971       Research Scientist   7       NaN       NaN       NaN  ...
# 25972           Data Scientist   4    Python       NaN       SQL  ...
# 25973         Business Analyst   7       NaN       NaN       NaN  ...
#
#       Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7  \
# 2              NaN          NaN            NaN          NaN          NaN
# 3              NaN          NaN   TensorBoard           NaN          NaN
# 4              NaN          NaN            NaN          NaN          NaN
# 5              NaN          NaN            NaN          NaN          NaN
# 6              NaN          NaN            NaN    Guild.ai           NaN
# ...            ...          ...            ...          ...          ...
# 25969          NaN          NaN            NaN          NaN          NaN
# 25970          NaN          NaN            NaN          NaN          NaN
# 25971          NaN          NaN            NaN          NaN          NaN
# 25972          NaN          NaN            NaN          NaN          NaN
# 25973          NaN          NaN            NaN          NaN          NaN
#
#       Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 2              NaN          NaN           NaN          None         NaN
# 3              NaN          NaN           NaN           NaN         NaN
# 4              NaN          NaN           NaN          None         NaN
# 5              NaN          NaN           NaN           NaN         NaN
# 6              NaN          NaN       MLflow            NaN         NaN
# ...            ...          ...           ...           ...         ...
# 25969          NaN          NaN           NaN           NaN         NaN
# 25970          NaN          NaN           NaN           NaN         NaN
# 25971          NaN          NaN           NaN          None         NaN
# 25972          NaN          NaN           NaN           NaN         NaN
# 25973          NaN          NaN           NaN          None         NaN
#
# [25972 rows x 369 columns]

# %%
df_r.drop(df_r[df_r["Q25"].isin()].index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-fa927f62c4a5> in <module>
# ----> 1 df_r.drop(df_r[df_r["Q25"].isin()].index)
#
# TypeError: isin() missing 1 required positional argument: 'values'

# %%
np.corrcoef(df_r["Q25"],df_r["Q6"])
# Out:
# array([[nan, nan],
#        [nan,  1.]])

# %%
df_r["Q25"]
# Out:
# 2        12.0
# 3         1.0
# 4         4.0
# 5         4.0
# 6         NaN
#          ...
# 25969    10.0
# 25970     NaN
# 25971     1.0
# 25972     NaN
# 25973     1.0
# Name: Q25, Length: 25972, dtype: float64

# %%
x = [1,3,6,2,3,3]
y = [1,4,4,2,3,3]
r = np.corrcoef(x, y)
r
# Out:
# array([[1.        , 0.81791781],
#        [0.81791781, 1.        ]])

# %%
df_r
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 2                                     784  50-54    Man
# 3                                     924  22-24    Man
# 4                                     575  45-49    Man
# 5                                     781  45-49    Man
# 6                                    1020  25-29  Woman
# ...                                   ...    ...    ...
# 25969                                1756  30-34    Man
# 25970                                 253  22-24    Man
# 25971                                 494  50-54    Man
# 25972                                 277  45-49    Man
# 25973                                 255  18-21    Man
#
#                              Q3                      Q4  \
# 2                     Indonesia         Master’s degree
# 3                      Pakistan         Master’s degree
# 4                        Mexico         Doctoral degree
# 5                         India         Doctoral degree
# 6                         India  I prefer not to answer
# ...                         ...                     ...
# 25969                     Egypt       Bachelor’s degree
# 25970                     China         Master’s degree
# 25971                    Sweden         Doctoral degree
# 25972  United States of America         Master’s degree
# 25973                     India       Bachelor’s degree
#
#                             Q5  Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 2      Program/Project Manager   6       NaN       NaN       SQL  ...
# 3            Software Engineer   1    Python       NaN       NaN  ...
# 4           Research Scientist   6    Python       NaN       NaN  ...
# 5                        Other   2    Python       NaN       NaN  ...
# 6       Currently not employed   2    Python       NaN       NaN  ...
# ...                        ...  ..       ...       ...       ...  ...
# 25969             Data Analyst   1    Python       NaN       SQL  ...
# 25970                  Student   1    Python       NaN       NaN  ...
# 25971       Research Scientist   7       NaN       NaN       NaN  ...
# 25972           Data Scientist   4    Python       NaN       SQL  ...
# 25973         Business Analyst   7       NaN       NaN       NaN  ...
#
#       Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7  \
# 2              NaN          NaN            NaN          NaN          NaN
# 3              NaN          NaN   TensorBoard           NaN          NaN
# 4              NaN          NaN            NaN          NaN          NaN
# 5              NaN          NaN            NaN          NaN          NaN
# 6              NaN          NaN            NaN    Guild.ai           NaN
# ...            ...          ...            ...          ...          ...
# 25969          NaN          NaN            NaN          NaN          NaN
# 25970          NaN          NaN            NaN          NaN          NaN
# 25971          NaN          NaN            NaN          NaN          NaN
# 25972          NaN          NaN            NaN          NaN          NaN
# 25973          NaN          NaN            NaN          NaN          NaN
#
#       Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 2              NaN          NaN           NaN          None         NaN
# 3              NaN          NaN           NaN           NaN         NaN
# 4              NaN          NaN           NaN          None         NaN
# 5              NaN          NaN           NaN           NaN         NaN
# 6              NaN          NaN       MLflow            NaN         NaN
# ...            ...          ...           ...           ...         ...
# 25969          NaN          NaN           NaN           NaN         NaN
# 25970          NaN          NaN           NaN           NaN         NaN
# 25971          NaN          NaN           NaN          None         NaN
# 25972          NaN          NaN           NaN           NaN         NaN
# 25973          NaN          NaN           NaN          None         NaN
#
# [25972 rows x 369 columns]

# %%
df_r["Q25"]
# Out:
# 2        12.0
# 3         1.0
# 4         4.0
# 5         4.0
# 6         NaN
#          ...
# 25969    10.0
# 25970     NaN
# 25971     1.0
# 25972     NaN
# 25973     1.0
# Name: Q25, Length: 25972, dtype: float64

# %%
df_r["Q6"]
# Out:
# 2        6
# 3        1
# 4        6
# 5        2
# 6        2
#         ..
# 25969    1
# 25970    1
# 25971    7
# 25972    4
# 25973    7
# Name: Q6, Length: 25972, dtype: int64

# %%
dff = df_r.dropna(subset=["Q25"])
dff
# Out:
#       Time from Start to Finish (seconds)     Q1   Q2           Q3  \
# 2                                     784  50-54  Man    Indonesia
# 3                                     924  22-24  Man     Pakistan
# 4                                     575  45-49  Man       Mexico
# 5                                     781  45-49  Man        India
# 8                                     484  30-34  Man        India
# ...                                   ...    ...  ...          ...
# 25967                                 323  30-34  Man        India
# 25968                                 910  35-39  Man  South Korea
# 25969                                1756  30-34  Man        Egypt
# 25971                                 494  50-54  Man       Sweden
# 25973                                 255  18-21  Man        India
#
#                       Q4                       Q5  Q6 Q7_Part_1 Q7_Part_2  \
# 2        Master’s degree  Program/Project Manager   6       NaN       NaN
# 3        Master’s degree        Software Engineer   1    Python       NaN
# 4        Doctoral degree       Research Scientist   6    Python       NaN
# 5        Doctoral degree                    Other   2    Python       NaN
# 8      Bachelor’s degree           Data Scientist   4    Python       NaN
# ...                  ...                      ...  ..       ...       ...
# 25967  Bachelor’s degree             Data Analyst   1    Python       NaN
# 25968  Bachelor’s degree        Software Engineer   4    Python       NaN
# 25969  Bachelor’s degree             Data Analyst   1    Python       NaN
# 25971    Doctoral degree       Research Scientist   7       NaN       NaN
# 25973  Bachelor’s degree         Business Analyst   7       NaN       NaN
#
#       Q7_Part_3  ... Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6  \
# 2           SQL  ...          NaN          NaN            NaN          NaN
# 3           NaN  ...          NaN          NaN   TensorBoard           NaN
# 4           NaN  ...          NaN          NaN            NaN          NaN
# 5           NaN  ...          NaN          NaN            NaN          NaN
# 8           NaN  ...          NaN          NaN            NaN          NaN
# ...         ...  ...          ...          ...            ...          ...
# 25967       NaN  ...          NaN          NaN            NaN          NaN
# 25968       SQL  ...          NaN          NaN            NaN          NaN
# 25969       SQL  ...          NaN          NaN            NaN          NaN
# 25971       NaN  ...          NaN          NaN            NaN          NaN
# 25973       NaN  ...          NaN          NaN            NaN          NaN
#
#       Q38_B_Part_7 Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11  \
# 2              NaN          NaN          NaN           NaN          None
# 3              NaN          NaN          NaN           NaN           NaN
# 4              NaN          NaN          NaN           NaN          None
# 5              NaN          NaN          NaN           NaN           NaN
# 8              NaN          NaN          NaN           NaN           NaN
# ...            ...          ...          ...           ...           ...
# 25967          NaN          NaN          NaN           NaN           NaN
# 25968          NaN          NaN          NaN           NaN           NaN
# 25969          NaN          NaN          NaN           NaN           NaN
# 25971          NaN          NaN          NaN           NaN          None
# 25973          NaN          NaN          NaN           NaN          None
#
#       Q38_B_OTHER
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 8             NaN
# ...           ...
# 25967         NaN
# 25968         NaN
# 25969         NaN
# 25971         NaN
# 25973         NaN
#
# [15390 rows x 369 columns]

# %%
np.corrcoef(dff["Q25"],dff["Q6"])
# Out:
# array([[1.        , 0.19241124],
#        [0.19241124, 1.        ]])

# %%
plt.scatter(dff["Q6"],dff["Q25"])

# %%
import plotly.graph_objects as go

# %%
survey19 = pd.read_csv('/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/multiple_choice_responses.csv',header=None)
survey20 = pd.read_csv('/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/kaggle_survey_2020_responses.csv',header=None)
survey21 = pd.read_csv('/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/kaggle_survey_2021_responses.csv',header=None)
# Out:
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning:
#
# Columns (0,3,7,19,34,47,49,50,51,52,53,54,68,81,94,96,109,115,130,139,147,154,167,180,193,206,219,232,245) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning:
#
# Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning:
#
# Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
survey19
# Out:
#                                        0                            1    \
# 0      Time from Start to Finish (seconds)                           Q1
# 1                    Duration (in seconds)  What is your age (# years)?
# 2                                      510                        22-24
# 3                                      423                        40-44
# 4                                       83                        55-59
# ...                                    ...                          ...
# 19714                                   84                        50-54
# 19715                                  473                        18-21
# 19716                                 9195                        35-39
# 19717                                  176                        25-29
# 19718                                  567                        50-54
#
#                                           2    \
# 0                                          Q2
# 1      What is your gender? - Selected Choice
# 2                                        Male
# 3                                        Male
# 4                                      Female
# ...                                       ...
# 19714                                    Male
# 19715                                    Male
# 19716                                    Male
# 19717                                    Male
# 19718                                    Male
#
#                                                      3    \
# 0                                          Q2_OTHER_TEXT
# 1      What is your gender? - Prefer to self-describe...
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# ...                                                  ...
# 19714                                                 -1
# 19715                                                 -1
# 19716                                                 -1
# 19717                                                 -1
# 19718                                                 -1
#
#                                              4    \
# 0                                             Q3
# 1      In which country do you currently reside?
# 2                                         France
# 3                                          India
# 4                                        Germany
# ...                                          ...
# 19714                                      Japan
# 19715                                      India
# 19716                                      India
# 19717                                      India
# 19718                                     France
#
#                                                      5    \
# 0                                                     Q4
# 1      What is the highest level of formal education ...
# 2                                        Master’s degree
# 3                                    Professional degree
# 4                                    Professional degree
# ...                                                  ...
# 19714                                                NaN
# 19715                                  Bachelor’s degree
# 19716                                    Master’s degree
# 19717                                    Master’s degree
# 19718                                  Bachelor’s degree
#
#                                                      6    \
# 0                                                     Q5
# 1      Select the title most similar to your current ...
# 2                                      Software Engineer
# 3                                      Software Engineer
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                              Other
# 19716                                            Student
# 19717                                       Statistician
# 19718                                  Software Engineer
#
#                                                      7    \
# 0                                          Q5_OTHER_TEXT
# 1      Select the title most similar to your current ...
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# ...                                                  ...
# 19714                                                 -1
# 19715                                                 -1
# 19716                                                 -1
# 19717                                                 -1
# 19718                                                 -1
#
#                                                      8    \
# 0                                                     Q6
# 1      What is the size of the company where you are ...
# 2                                   1000-9,999 employees
# 3                                     > 10,000 employees
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                  250-999 employees
# 19716                                                NaN
# 19717                                   50-249 employees
# 19718                                 > 10,000 employees
#
#                                                      9    ...  \
# 0                                                     Q7  ...
# 1      Approximately how many individuals are respons...  ...
# 2                                                      0  ...
# 3                                                    20+  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 19714                                                NaN  ...
# 19715                                                3-4  ...
# 19716                                                NaN  ...
# 19717                                              15-19  ...
# 19718                                                20+  ...
#
#                                                      236  \
# 0                                             Q34_Part_4
# 1      Which of the following relational database pro...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
# 19718                                                NaN
#
#                                                      237  \
# 0                                             Q34_Part_5
# 1      Which of the following relational database pro...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
# 19718                                                NaN
#
#                                                      238  \
# 0                                             Q34_Part_6
# 1      Which of the following relational database pro...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
# 19718                                                NaN
#
#                                                      239  \
# 0                                             Q34_Part_7
# 1      Which of the following relational database pro...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
# 19718                                                NaN
#
#                                                      240  \
# 0                                             Q34_Part_8
# 1      Which of the following relational database pro...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
# 19718                                                NaN
#
#                                                      241  \
# 0                                             Q34_Part_9
# 1      Which of the following relational database pro...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
# 19718                                                NaN
#
#                                                      242  \
# 0                                            Q34_Part_10
# 1      Which of the following relational database pro...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
# 19718                                                NaN
#
#                                                      243  \
# 0                                            Q34_Part_11
# 1      Which of the following relational database pro...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
# 19718                                                NaN
#
#                                                      244  \
# 0                                            Q34_Part_12
# 1      Which of the following relational database pro...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
# 19718                                                NaN
#
#                                                      245
# 0                                         Q34_OTHER_TEXT
# 1      Which of the following relational database pro...
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# ...                                                  ...
# 19714                                                 -1
# 19715                                                 -1
# 19716                                                 -1
# 19717                                                 -1
# 19718                                                 -1
#
# [19719 rows x 246 columns]

# %%
df_N = pd.Data

# %%
survey19_ = pd.read_csv('/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/multiple_choice_responses.csv')
# Out:
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning:
#
# Columns (0,3,7,19,34,47,49,50,51,52,53,54,68,81,94,96,109,115,130,139,147,154,167,180,193,206,219,232,245) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
Q7_2019 = list(survey19.loc[0][82:95])
df7_2019 = survey19_[Q7_2019]
df7_2019
Q2019 = list (df7_2019.count())
Q2019
# Out:
# [12842, 4589, 6533, 1673, 2257, 2268, 2175, 390, 2038, 1517, 84, 1149, 19718]

# %%
Q7_2020 = list(survey20.loc[0][7:20])
Q7_2020
# Out:
# ['Q7_Part_1',
#  'Q7_Part_2',
#  'Q7_Part_3',
#  'Q7_Part_4',
#  'Q7_Part_5',
#  'Q7_Part_6',
#  'Q7_Part_7',
#  'Q7_Part_8',
#  'Q7_Part_9',
#  'Q7_Part_10',
#  'Q7_Part_11',
#  'Q7_Part_12',
#  'Q7_OTHER']

# %%
df7_2021 = df[Q7_2021]
df7_2021.count()
Q2021 = list (df7_2021.count())

# %%
[15531,4278,7536,3316,3828,3368,2996,199,1777,2218,2218,207,1946]

# %%
survey20_ = pd.read_csv('/Users/nouf/Desktop/2021-Kaggle-ML-and-DS-Survey/kaggle_survey_2020_responses.csv')
# Out:
# /Users/nouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning:
#
# Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df7_2020 = survey20_[Q7_2020]
Q2020 = list (df7_2020.count())

# %%
Q18_Part_1        12842
Q18_Part_2         4589
Q18_Part_3         6533
Q18_Part_4         1673
Q18_Part_5         2257
Q18_Part_6         2268
Q18_Part_7         2175
Q18_Part_8          390
Q18_Part_9         2038
Q18_Part_10        1517
Q18_Part_11          84
Q18_Part_12        1149
Q18_OTHER_TEXT    19718
dtype: int64

# %%
plotdata = pd.DataFrame({
    "2019":Q2019,    
    "2020":Q2020,
    "2021":Q2021
    }, 
    index= ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 'Javascript', 'Julia', 'Swift', 'Bash', 'MATLAB', 'None', 'Other']
)
sns.set(style='darkgrid')
plotdata.plot(kind="bar")
plt.title("")
plt.xlabel("")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
plotdata
# Out:
#              2019   2020   2021
# Python      12842  15531  21861
# R            4589   4278   5335
# SQL          6533   7536  10757
# C            1673   3316   4710
# C++          2257   3828   5536
# Java         2268   3368   4770
# Javascript   2175   2996   4333
# Julia         390    199    306
# Swift        2038   1777    243
# Bash         1517   2218   2217
# MATLAB         84   2218   2936
# None         1149    207    320
# Other       19718   1946   2576

# %%
df7_2020.count()
# Out:
# Q7_Part_1     15531
# Q7_Part_2      4278
# Q7_Part_3      7536
# Q7_Part_4      3316
# Q7_Part_5      3828
# Q7_Part_6      3368
# Q7_Part_7      2996
# Q7_Part_8       263
# Q7_Part_9       199
# Q7_Part_10     1777
# Q7_Part_11     2218
# Q7_Part_12      207
# Q7_OTHER       1946
# dtype: int64

# %%
plt.figure(figsize=(15, 11))
sns.countplot(data=df, x=df['Q6'], hue=df['Q4'], order=df['Q6'].value_counts().index)
sns.despine()
plt.title('Men students in defferent degrees.')
plt.xlabel('')
plt.ylabel('Count')
plt.show()
